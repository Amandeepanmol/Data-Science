# %% [markdown]
# # Data cleaning
#
# I have use the data from kaggle(link is here)-> https://www.kaggle.com/patrickb1912/ipl-complete-dataset-20082020

# %%
import pandas as pd
df=pd.read_csv('C:/Users/hp/IPL.csv')
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.shape         # NO OF ROWS AND COLUMNS
# Out:
# (816, 17)

# %%
df.info()                   # MORE INFORMATION THAN shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df['id']
# Out:
# 0       335982
# 1       335983
# 2       335984
# 3       335985
# 4       335986
#         ...
# 811    1216547
# 812    1237177
# 813    1237178
# 814    1237180
# 815    1237181
# Name: id, Length: 816, dtype: int64

# %%
df.columns               # NAME OF ALL COLUMNS
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df['winner']
# Out:
# 0            Kolkata Knight Riders
# 1              Chennai Super Kings
# 2                 Delhi Daredevils
# 3      Royal Challengers Bangalore
# 4            Kolkata Knight Riders
#                   ...
# 811    Royal Challengers Bangalore
# 812                 Mumbai Indians
# 813            Sunrisers Hyderabad
# 814                 Delhi Capitals
# 815                 Mumbai Indians
# Name: winner, Length: 816, dtype: object

# %%
df['player_of_match']      # NAME OF PLAYER WHO BECOME player_of_match
# Out:
# 0         BB McCullum
# 1          MEK Hussey
# 2         MF Maharoof
# 3          MV Boucher
# 4           DJ Hussey
#             ...
# 811    AB de Villiers
# 812         JJ Bumrah
# 813     KS Williamson
# 814        MP Stoinis
# 815          TA Boult
# Name: player_of_match, Length: 816, dtype: object

# %%
df.iloc[[0,3],2]                  # ACCESS THE ELEMENT
# Out:
# 0    2008-04-18
# 3    2008-04-20
# Name: date, dtype: object

# %%
df['player_of_match']=='AB de Villiers'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 811     True
# 812    False
# 813    False
# 814    False
# 815    False
# Name: player_of_match, Length: 816, dtype: bool

# %%
filt=(df['player_of_match']=='AB de Villiers')

# %%
df[filt]
# Out:
#           id          city        date player_of_match  \
# 65    392189        Durban  2009-04-23  AB de Villiers
# 105   392230  Bloemfontein  2009-05-17  AB de Villiers
# 177   501200         Kochi  2011-04-09  AB de Villiers
# 252   548310     Bangalore  2012-04-07  AB de Villiers
# 278   548336        Jaipur  2012-04-23  AB de Villiers
# 296   548356     Bangalore  2012-05-06  AB de Villiers
# 366   598042          Pune  2013-05-02  AB de Villiers
# 421   733977     Bangalore  2014-05-04  AB de Villiers
# 439   734013        Ranchi  2014-05-18  AB de Villiers
# 502   829795        Mumbai  2015-05-10  AB de Villiers
# 514   829819          Pune  2015-05-20  AB de Villiers
# 520   980907     Bangalore  2016-04-12  AB de Villiers
# 532   980931          Pune  2016-04-22  AB de Villiers
# 560   980987     Bangalore  2016-05-14  AB de Villiers
# 573   981013     Bangalore  2016-05-24  AB de Villiers
# 654  1136579     Bengaluru  2018-04-21  AB de Villiers
# ...

# %%
filt1=(df['player_of_match']=='AB de Villiers') & (df['toss_decision']=='bat')

# %%
df[filt1]             # NO OF TIME  AB de Villiers WAS player_of_match WHEN RCB BATTED
# Out:
#           id          city        date player_of_match  \
# 65    392189        Durban  2009-04-23  AB de Villiers
# 105   392230  Bloemfontein  2009-05-17  AB de Villiers
# 177   501200         Kochi  2011-04-09  AB de Villiers
# 366   598042          Pune  2013-05-02  AB de Villiers
# 439   734013        Ranchi  2014-05-18  AB de Villiers
# 502   829795        Mumbai  2015-05-10  AB de Villiers
# 514   829819          Pune  2015-05-20  AB de Villiers
# 786  1216522         Dubai  2020-10-17  AB de Villiers
# 804  1216540       Sharjah  2020-10-12  AB de Villiers
#
#                                        venue  neutral_venue  \
# 65                                 Kingsmead              1
# 105                          OUTsurance Oval              1
# 177                            Nehru Stadium              0
# 366               Subrata Roy Sahara Stadium              0
# 439       JSCA International Stadium Complex              0
# ...

# %%
df.sort_values(by="date")    # SORT VALUE IN ASCENDING ORDER
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 759  1216495     Sharjah  2020-11-03        S Nadeem
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.sort_values(by="date",ascending=False)      # SORT DATE IN DESCENDING ORDER
# Out:
#           id        city        date player_of_match  \
# 815  1237181       Dubai  2020-11-10        TA Boult
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 759  1216495     Sharjah  2020-11-03        S Nadeem
# ..       ...         ...         ...             ...
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 0     335982   Bangalore  2008-04-18     BB McCullum
#
#                                           venue  neutral_venue  \
# 815         Dubai International Cricket Stadium              0
# 814                        Sheikh Zayed Stadium              0
# 813                        Sheikh Zayed Stadium              0
# 812         Dubai International Cricket Stadium              0
# ...

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df['toss_decision'].value_counts()         # COUNT OF FIELD AND BAT
# Out:
# field    496
# bat      320
# Name: toss_decision, dtype: int64

# %%
df['winner'].value_counts()       # TEAMS WITH MOST WINS IN IP TILL DATE
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
filt1=df['winner']=='Royal Challengers Bangalore'
df.loc[filt1]                                          # IT WILL GIVES INDEX WHEN RCB WIN THE MATCH
# Out:
#           id       city        date player_of_match  \
# 3     335985     Mumbai  2008-04-20      MV Boucher
# 20    336002  Hyderabad  2008-05-25   R Vinay Kumar
# 47    336029    Chennai  2008-05-21        A Kumble
# 51    336034  Bangalore  2008-05-03         P Kumar
# 59    392182  Cape Town  2009-04-18        R Dravid
# ..       ...        ...         ...             ...
# 786  1216522      Dubai  2020-10-17  AB de Villiers
# 789  1216525      Dubai  2020-10-10         V Kohli
# 798  1216534      Dubai  2020-09-21       YS Chahal
# 804  1216540    Sharjah  2020-10-12  AB de Villiers
# 811  1216547      Dubai  2020-09-28  AB de Villiers
#
#                                          venue  neutral_venue  \
# 3                             Wankhede Stadium              0
# 20   Rajiv Gandhi International Stadium, Uppal              0
# 47             MA Chidambaram Stadium, Chepauk              0
# 51                       M Chinnaswamy Stadium              0
# ...

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df_new=df.fillna('no event')
df_new                                   # missing value can be replaced
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...
