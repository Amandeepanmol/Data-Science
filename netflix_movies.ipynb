# %% [markdown]
# # Data cleaning(basics)
#
# I have use the data from kaggle(link is here)-> https://www.kaggle.com/shivamb/netflix-shows/tasks

# %%
import pandas as pd
df=pd.read_csv("C:/Users/hp/netflix_titles.csv")
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
df.info()          #it gives information about rows,columns,data type etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
df.shape    #it gives total no of rows and columns
# Out:
# (6234, 12)

# %%
df.head(100)      #it gives first 100 entry of csv file
# Out:
#      show_id     type                                    title  \
# 0   81145628    Movie  Norm of the North: King Sized Adventure
# 1   80117401    Movie               Jandino: Whatever it Takes
# 2   70234439  TV Show                       Transformers Prime
# 3   80058654  TV Show         Transformers: Robots in Disguise
# 4   80125979    Movie                             #realityhigh
# ..       ...      ...                                      ...
# 95  81016750    Movie                              The 3rd Eye
# 96  81002866    Movie             The Sinking Of Van Der Wijck
# 97  80992039    Movie                           Two Catalonias
# 98  80126507    Movie                     Bobby Sands: 66 Days
# 99  80225885  TV Show                            Bard of Blood
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# ...

# %%
df.tail()    #it give ous last entrys of table ie 5 is default
# Out:
#        show_id     type                                        title director  \
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
#                                                    cast         country  \
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 6231                                                NaN             NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
#
#      date_added  release_year rating    duration  \
# ...

# %%
df.tail(10)
# Out:
#        show_id     type                                        title director  \
# 6224  70304979  TV Show              Anthony Bourdain: Parts Unknown      NaN
# 6225  70153412  TV Show                                      Frasier      NaN
# 6226  70243132  TV Show                          La Familia P. Luche      NaN
# 6227  80005756  TV Show                 The Adventures of Figaro Pho      NaN
# 6228  80159925  TV Show                                     Kikoriki      NaN
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
#                                                    cast         country  \
# ...

# %%
df.columns          #it gives ous the column name in table
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df['title']
# Out:
# 0           Norm of the North: King Sized Adventure
# 1                        Jandino: Whatever it Takes
# 2                                Transformers Prime
# 3                  Transformers: Robots in Disguise
# 4                                      #realityhigh
#                            ...
# 6229                                   Red vs. Blue
# 6230                                          Maron
# 6231         Little Baby Bum: Nursery Rhyme Friends
# 6232    A Young Doctor's Notebook and Other Stories
# 6233                                        Friends
# Name: title, Length: 6234, dtype: object

# %%
filt=df['title']=='Friends'
df[filt]                           # it  gives ous the row which conatins title as Friends
# Out:
#        show_id     type    title director  \
# 6233  70153404  TV Show  Friends      NaN
#
#                                                    cast        country  \
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...  United States
#
#      date_added  release_year rating    duration  \
# 6233        NaN          2003  TV-14  10 Seasons
#
#                            listed_in  \
# 6233  Classic & Cult TV, TV Comedies
#
#                                             description
# 6233  This hit sitcom follows the merry misadventure...

# %%
df.dropna(axis='columns',how='any',inplace=True)        #remove all NaN value in table

# %%
df     #now all columns containing NaN value is removed
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#       release_year    duration  \
# 0             2019      90 min
# 1             2016      94 min
# 2             2013    1 Season
# ...

# %%
filt=df['listed_in']=="Kids' TV"
df[filt]
# Out:
#        show_id     type                             title  release_year  \
# 2     70234439  TV Show                Transformers Prime          2013
# 3     80058654  TV Show  Transformers: Robots in Disguise          2016
# 64    80239337  TV Show                            Ben 10          2016
# 149   80115346  TV Show                             Hilda          2018
# 175   80057610  TV Show        Kulipari: An Army of Frogs          2016
# ...        ...      ...                               ...           ...
# 6184  80003196  TV Show                             Wakfu          2017
# 6189  80115432  TV Show               Spirit: Riding Free          2019
# 6216  80108373  TV Show  The Magic School Bus Rides Again          2018
# 6220  70272742  TV Show                       Justin Time          2012
# 6228  80159925  TV Show                          Kikoriki          2010
#
#        duration listed_in                                        description
# ...

# %%
df['type']
# Out:
# 0         Movie
# 1         Movie
# 2       TV Show
# 3       TV Show
# 4         Movie
#          ...
# 6229    TV Show
# 6230    TV Show
# 6231      Movie
# 6232    TV Show
# 6233    TV Show
# Name: type, Length: 6234, dtype: object

# %%
df.drop_duplicates(subset='release_year')          # it remove dupliactes value
# Out:
#        show_id     type                                    title  \
# 0     81145628    Movie  Norm of the North: King Sized Adventure
# 1     80117401    Movie               Jandino: Whatever it Takes
# 2     70234439  TV Show                       Transformers Prime
# 4     80125979    Movie                             #realityhigh
# 6     70304989    Movie                                 Automata
# ...        ...      ...                                      ...
# 3138  80158390    Movie                                 Amrapali
# 3147  80158481    Movie                              Lal Patthar
# 4227  60002818    Movie                                   Sangam
# 4292  81030762  TV Show        Pioneers: First Women Filmmakers*
# 5981  70172488  TV Show      The Twilight Zone (Original Series)
#
#       release_year   duration  \
# 0             2019     90 min
# 1             2016     94 min
# 2             2013   1 Season
# 4             2017     99 min
# ...

# %%
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#       release_year    duration  \
# 0             2019      90 min
# 1             2016      94 min
# 2             2013    1 Season
# ...

# %%
df.columns=df.columns.str.replace('_','@')

# %%
df
# Out:
#        show@id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#       release@year    duration  \
# 0             2019      90 min
# 1             2016      94 min
# 2             2013    1 Season
# ...

# %%
df.rename(columns={'show@id':'show_id','release@year':'release_year'})
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#       release_year    duration  \
# 0             2019      90 min
# 1             2016      94 min
# 2             2013    1 Season
# ...

# %%
df.count()
# Out:
# show@id         6234
# type            6234
# title           6234
# release@year    6234
# duration        6234
# listed@in       6234
# description     6234
# dtype: int64

# %%
df.size
# Out:
# 43638

# %%
df.loc[6234]=[70281029,'TV Show','Avengers',2012,'5 Seasons','Adventure','Fight between villian and hero']    #by this we can insert new value in table

# %%
df    # new value is inserted
# Out:
#        show@id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
# 6234  70281029  TV Show                                     Avengers
#
#       release@year    duration                                 listed@in  \
# ...

# %%
df['type'].str.upper()        #by this we can convert all row in upper case
# Out:
# 0         MOVIE
# 1         MOVIE
# 2       TV SHOW
# 3       TV SHOW
# 4         MOVIE
#          ...
# 6230    TV SHOW
# 6231      MOVIE
# 6232    TV SHOW
# 6233    TV SHOW
# 6234    TV SHOW
# Name: type, Length: 6235, dtype: object

# %%
df.describe()             #it gives ous bunch of value at one place
# Out:
#             show@id  release@year
# count  6.235000e+03   6235.000000
# mean   7.670265e+07   2013.359102
# std    1.094239e+07      8.810930
# min    2.477470e+05   1925.000000
# 25%    8.003569e+07   2013.000000
# 50%    8.016337e+07   2016.000000
# 75%    8.024488e+07   2018.000000
# max    8.123573e+07   2020.000000

# %%
filt=df['title'].str.contains('Jandino: Whatever it Takes')
df[filt]                                                  # by this we can find particular thing in table
# Out:
#     show@id   type                       title  release@year duration  \
# 1  80117401  Movie  Jandino: Whatever it Takes          2016   94 min
#
#          listed@in                                        description
# 1  Stand-Up Comedy  Jandino Asporaat riffs on the challenges of ra...

# %%
df['type'].drop_duplicates()
# Out:
# 0      Movie
# 2    TV Show
# Name: type, dtype: object

# %%
df['type'].value_counts()    #it gives ous occurence of  the value
# Out:
# Movie      4265
# TV Show    1970
# Name: type, dtype: int64
